# %% [markdown]
# ![Texte alternatif…](https://)

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip -P /resources/data
# Out:
# --2020-03-31 12:26:00--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 245259777 (234M) [application/zip]
# Saving to: ‘/resources/data/concrete_crack_images_for_classification.zip’
#
# concrete_crack_imag 100%[===================>] 233.90M  32.3MB/s    in 7.3s
#
# 2020-03-31 12:26:07 (31.9 MB/s) - ‘/resources/data/concrete_crack_images_for_classification.zip’ saved [245259777/245259777]

# %%
from PIL import Image
from matplotlib.pyplot import imshow
import pandas
import matplotlib.pylab as plt
import os
import glob

# %%
def show_data(data_sample, shape = (28, 28)):
    plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
    plt.title('y = ' + data_sample[1])

# %%
directory="/resources/data"

# %%
negative='Negative'

# %%
negative_file_path=os.path.join(directory,negative)
negative_file_path
# Out:
# '/resources/data/Negative'

# %%
# !unzip -q  /resources/data/concrete_crack_images_for_classification.zip -d  /resources/data

# %%
 os.listdir(negative_file_path)[0:3]
# Out:
# ['09412.jpg', '18041.jpg', '12322.jpg']

# %%
[os.path.join(negative_file_path,file) for file in  os.listdir(negative_file_path)][0:3]
# Out:
# ['/resources/data/Negative/09412.jpg',
#  '/resources/data/Negative/18041.jpg',
#  '/resources/data/Negative/12322.jpg']

# %%
print("test.jpg".endswith(".jpg"))
print("test.mpg".endswith(".jpg"))
# Out:
# True
# False

# %%
negative_files=[os.path.join(negative_file_path,file) for file in  os.listdir(negative_file_path) if file.endswith(".jpg")]
negative_files.sort()
negative_files[0:3]
# Out:
# ['/resources/data/Negative/00001.jpg',
#  '/resources/data/Negative/00002.jpg',
#  '/resources/data/Negative/00003.jpg']

# %%
positive="Positive"

# %%
positive_file_path=os.path.join(directory,positive)
positive_file_path
# Out:
# '/resources/data/Positive'

# %%
 os.listdir(positive_file_path)[0:3]
# Out:
# ['18863_1.jpg', '16589_1.jpg', '09412.jpg']

# %%
[os.path.join(positive_file_path,file) for file in  os.listdir(positive_file_path)][0:3]
# Out:
# ['/resources/data/Positive/18863_1.jpg',
#  '/resources/data/Positive/16589_1.jpg',
#  '/resources/data/Positive/09412.jpg']

# %%
print("test.jpg".endswith(".jpg"))
print("test.mpg".endswith(".jpg"))
# Out:
# True
# False

# %%
positive_files=[os.path.join(positive_file_path,file) for file in  os.listdir(positive_file_path) if file.endswith(".jpg")]
positive_files.sort()
positive_files[0:3]
# Out:
# ['/resources/data/Positive/00001.jpg',
#  '/resources/data/Positive/00002.jpg',
#  '/resources/data/Positive/00003.jpg']

# %%
image1 = Image.open(negative_files[0])
# you can view the image directly 
#image

# %%
plt.imshow(image1)
plt.title("1st Image With No Cracks")
plt.show()

# %%
image2 = Image.open(negative_files[1])
plt.imshow(image2)
plt.title("2nd Image With No Cracks")
plt.show()

# %%
positive_files=[os.path.join(positive_file_path,file) for file in  os.listdir(positive_file_path) if file.endswith(".jpg")]
positive_files.sort()
positive_files[0:3]
# Out:
# ['/resources/data/Positive/00001.jpg',
#  '/resources/data/Positive/00002.jpg',
#  '/resources/data/Positive/00003.jpg']

# %%
## You can use this cell to type your code to answer the above question
for i in range(0,3):
    print(positive_files[i])
    image = Image.open(positive_files[i])
    plt.imshow(image)
    plt.title("Images With Cracks")
    plt.show()
# Out:
# /resources/data/Positive/00001.jpg
# /resources/data/Positive/00002.jpg
# /resources/data/Positive/00003.jpg
